# %% [markdown]
# # HomeWork 2

# %% [markdown]
# ## Домашнее задание 1

# %% [markdown]
# - Скачать данные по ссылке https://www.kaggle.com/datasets/ionaskel/laptop-prices

# %% [markdown]
# - id - Уникальный ID для каждого дома
# - date - Дата продажи дома
# - price - Стоимость продажи дома
# - bedrooms - Кол-во спален
# - bathrooms - Кол-во ванных комнат (0.5 - туалет без душа)
# - sqft_living - Кв. метры жилые
# - sqft_lot - Кв. метры общие
# - floors - Кол-во этажей
# - waterfront - Есть набержная или нет
# - view - Значение от 0 до 4 насколько хороший вид
# - condition - Значение от 1 до 5 насколько хорошее состояние
# - grade - Значение от 1 до 13, где 1-3 плохая конструкция здания и дизайн, 7 - средний уровень конструкции и дизайна, 11-13 - высокое качество конструкции и дизайна
# - sqft_above - Кв. метры дома, которые находятся выше земли
# - sqft_basement - Кв. метры дома, которые находятся ниже земли
# - yr_built - Год постройки дома
# - yr_renovated - Год ремонта дома
# - zipcode - Индекс
# - lat - Широтма
# - long - Долгота
# - sqft_living15 - Кв. метры жилой площади у 15 соседей
# - sqft_lot15 - Кв. метры общей площади у 15 соседей

# %% [markdown]
# - Считать данные с помощью pandas

# %%
import pandas as pd
df = pd.read_csv('./kc_house_data.csv')
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %% [markdown]
# - Вывести на экран первые 5 строк

# %%
df.head(5)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# - Посмотреть на описание признаков и на их содержание

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# ## Домашнее задание 2

# %% [markdown]
# Проведите первичный анализ данных
# - ### 1. Изучите типы данных

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# - ### 2. Найдите количество пропущенных ячеек в данных

# %%
df.empty
# Out:
# False

# %% [markdown]
# - ### 3. Посчитайте основные статистики по всем признакам и поизучайте их

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# - ### 4. Пишите выводы

# %% [markdown]
# Выводы : <br> 1. строк - 21 613,  <br> 2. столбцов - 21,  <br> 3. Типы данных: float64(5 строк), int64(15 строк), object(1 строка)

# %% [markdown]
# ## Домашнее задание 3

# %% [markdown]
# ### 3.1 В каком диапазоне изменяются стоимости недвижимости?

# %%
df['price'].min(),df['price'].max()
# Out:
# (75000.0, 7700000.0)

# %% [markdown]
# ### 3.2 Какую долю в среднем занимают жилая площадь от всей площади по всем домам?

# %%
df_living = df['sqft_living'].mean()
df_living
# Out:
# 2079.8997362698374

# %%
df_lot = df['sqft_lot'].mean()
df_lot
# Out:
# 15106.967565816869

# %%
round(df_living / df_lot*100,2)
# Out:
# 13.77

# %% [markdown]
# ### 3.3 Как много домов с разными этажами в данных?

# %%
df['floors'].unique()
# Out:
# array([1. , 2. , 1.5, 3. , 2.5, 3.5])

# %%
df['floors'].nunique()
# Out:
# 6

# %%
df['floors'].value_counts()
# Out:
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: floors, dtype: int64

# %% [markdown]
# ### 3.4 Насколько хорошие состояния у домов в данных?

# %%
df['condition'].value_counts()
# Out:
# 3    14031
# 4     5679
# 5     1701
# 2      172
# 1       30
# Name: condition, dtype: int64

# %%
round(df['condition'].value_counts(normalize=True)*100,2)
# Out:
# 3    64.92
# 4    26.28
# 5     7.87
# 2     0.80
# 1     0.14
# Name: condition, dtype: float64

# %% [markdown]
# ### 3.5 Найдите года, когда построили первый дом, когда построили последний дом в данных?

# %%
df['yr_built'].min(),df['yr_built'].max()
# Out:
# (1900, 2015)

# %% [markdown]
# ## Домашнее задание 4

# %% [markdown]
# ### 4.1 Сколько в среднем стоят дома, у которых 2 спальни?

# %%
df_two_bedrooms = df[(df['bedrooms']== 2)]
df_two_bedrooms
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 11     9212900260  20140527T000000  468000.0         2       1.00
# 18       16000397  20141205T000000  189000.0         2       1.00
# 23     8091400200  20140516T000000  252700.0         2       1.50
# 31     2426039314  20141201T000000  280000.0         2       1.50
# ...           ...              ...       ...       ...        ...
# 21586  2767604724  20141015T000000  505000.0         2       2.50
# 21588  2767600688  20141113T000000  414500.0         2       1.50
# 21595  1972201967  20141031T000000  520000.0         2       2.25
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 2              770     10000     1.0           0     0  ...      6
# ...

# %%
round(df_two_bedrooms['price'].mean(),2)
# Out:
# 401372.68

# %% [markdown]
# ### 4.2 Какая в среднем общая площадь домов, у которых стоимость больше 600 000?

# %%
df_cost = df[(df['price'] > 600000)]
df_cost
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 10     1736800520  20150403T000000   662500.0         3       2.50
# 15     9297300055  20150124T000000   650000.0         4       3.00
# 21     2524049179  20140826T000000  2000000.0         3       2.75
# ...           ...              ...        ...       ...        ...
# 21597   191100405  20150421T000000  1575000.0         4       3.25
# 21599  7202300110  20140915T000000   810000.0         4       3.00
# 21600   249000205  20141015T000000  1537000.0         5       3.75
# 21605  3448900210  20141014T000000   610685.0         4       2.50
# 21606  7936000429  20150326T000000  1007500.0         4       3.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 3             1960      5000     1.0           0     0  ...      7
# ...

# %%
round(df_cost['sqft_lot'].mean(),2)
# Out:
# 20442.52

# %% [markdown]
# ### 4.3 Как много домов коснулся ремонт?

# %%
df_renovated = df[(df['yr_renovated']!=0)]
df_renovated
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 35     9547205180  20140613T000000   696000.0         3       2.50
# 95     1483300570  20140908T000000   905000.0         4       2.50
# 103    2450000295  20141007T000000  1088000.0         3       2.50
# 115    3626039325  20141121T000000   740500.0         3       3.50
# ...           ...              ...        ...       ...        ...
# 19622  7351200295  20150114T000000  1150000.0         3       1.75
# 20057   126039256  20140904T000000   434900.0         3       2.00
# 20444  4305600360  20150225T000000   500012.0         4       2.50
# 20447  3319500628  20150212T000000   356999.0         3       1.50
# 20962  1278000210  20150311T000000   110000.0         2       1.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 1             2570      7242     2.0           0     0  ...      7
# ...

# %%
df_renovated.shape[0]
# Out:
# 914

# %% [markdown]
# ### 4.4 Насколько в среднем стоимость домов с оценкой grade домов выше 10 отличается от стоимости домов с оценкой grade меньше 4?

# %%
df_grade10 = round(df[df['grade']==10]['price'].mean(),2)
df_grade10
# Out:
# 1071771.07

# %%
df_grade4 = round(df[df['grade']==4]['price'].mean(),2)
df_grade4
# Out:
# 214381.03

# %%
df_devide = df_grade10 - df_grade4
df_devide
# Out:
# 857390.04

# %% [markdown]
# ## Домашнее задание 5

# %% [markdown]
# ### 5.1 Выберите дом клиенту

# %% [markdown]
# ###### Клиент хочет дом с видом на набережную, как минимум с тремя ванными и с подвалом. Сколько вариантов есть у клиента?

# %%
df_offer = df[(df['waterfront']!=0) & (df['bedrooms']>=3) & (df['sqft_basement']!=0)]
df_offer
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 49      822039084  20150311T000000  1350000.0         3       2.50
# 246    2025069065  20140929T000000  2400000.0         4       2.50
# 300    3225069065  20140624T000000  3075000.0         4       5.00
# 457    2122039094  20141126T000000   705000.0         3       3.00
# 656    3760500116  20141120T000000  3070000.0         3       2.50
# ...           ...              ...        ...       ...        ...
# 18914  9253900408  20150408T000000  1400000.0         3       2.75
# 20325   518500480  20140811T000000  3000000.0         3       3.50
# 20767  8043700105  20150417T000000  2300000.0         4       4.00
# 21201   518500460  20141008T000000  2230000.0         3       3.50
# 21576  9253900271  20150107T000000  3567000.0         5       4.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 49            2753     65005     1.0           1     2  ...      9
# ...

# %%
df_offer.shape[0]
# Out:
# 84

# %% [markdown]
# ### 5.2 Выберите дом клиенту

# %% [markdown]
# ###### Клиент хочет дом либо с очень красивым видом из окна, либо с видом на набережную, <br>в очень хорошем состоянии и год постройки не меньше 1980 года. В какой ценовом диапазоне будут дома?

# %%
df_offer1 = df[((df['view']==4) | (df['waterfront']!=0)) & (df['condition']==5) & (df['yr_built']>=1980)]
df_offer1
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 11257  3761100045  20140618T000000  3000000.0         4       4.25
# 14682  7278100515  20140821T000000  1295000.0         2       2.50
# 17312  3585901025  20140613T000000  1735000.0         3       2.50
# 18991  7856400300  20140702T000000  1411600.0         2       2.50
# 18992  7856400300  20150322T000000  1505000.0         2       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 11257         4850     12445     2.0           1     4  ...     10
# 14682         2910     19449     2.0           1     4  ...      9
# 17312         4310     32093     1.5           0     4  ...     10
# 18991         3180      9400     2.0           0     4  ...     10
# 18992         3180      9400     2.0           0     4  ...     10
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 11257        3850           1000      1989             0    98034  47.7011
# ...

# %%
df_offer1['price'].min(),df_offer1['price'].max()
# Out:
# (1295000.0, 3000000.0)

# %% [markdown]
# ### 5.3 Выберите дом клиенту

# %% [markdown]
# ###### Клиент хочет дом без подвала, с двумя этажами, стоимостью до 150000. Какая оценка по состоянию у таких домов в среднем?

# %%
df_offer2 = df[(df['sqft_basement']==0) & (df['floors']==2) & (df['price']<150000)]
df_offer2
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 2589   5061300030  20140508T000000  134000.0         2       1.50
# 10105  5466310060  20150324T000000  139500.0         2       1.50
# 15610  7614100080  20150211T000000  140000.0         3       1.75
# 18332  9272202260  20140924T000000  130000.0         3       1.00
# 18939  4239400300  20141129T000000   90000.0         3       1.00
# 18988  7399100210  20141126T000000  140000.0         3       1.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 2589           980      5000     2.0           0     0  ...      7
# 10105         1230      1561     2.0           0     0  ...      7
# 15610         1270      8991     2.0           0     0  ...      7
# 18332         1200      7000     2.0           0     0  ...      7
# 18939          980      2490     2.0           0     0  ...      6
# 18988         1200      2002     2.0           0     0  ...      8
#
# ...

# %%
round(df_offer2['condition'].mean(),0)
# Out:
# 3.0
